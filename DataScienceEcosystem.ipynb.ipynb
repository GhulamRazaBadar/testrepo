# %% [markdown]
# <h1> Data Science Tools and Ecosystem </h1>

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# Some of the commonly used languages used by Data Scientists include:
# <ol>
#   <li>Python</li>
#   <li>R Language</li>
#   <li>Julia</li>
# </ol>

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# <ol>
# <li>SciPy</li>
# <li>Matplotlib</li>
# <li>TensorFlow</li>
# </ol>

# %% [markdown]
# <table>
#     <thead>
#         <tr>
#             <th><h3>The table header</h3></th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#          <td>RStudio</td>
#         </tr>
#         <tr>
#             <td>Tensor Flow</td>
#        </tr>
#        <tr>
#             <td>Apache Hadoop</td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# <h3> Below are a few examples of evaluating arithmetic expressions in Python </h3>

# %%
A=10
B=5
print (A/B)
A=3
B=10
print (A*B)
A=8
B=5
print (A+B)
A=19
B=3
print (A-B)
# Out:
# 2.0
# 30
# 13
# 16

# %%
A=3
B=4
C=5
#This a simple arithmetic expression to mutiply then add integers#
print ((A*B)+C)
# Out:
# 17

# %%
from datetime import timedelta
minutes = 200/60
td = timedelta(minutes=minutes)
print(str(timedelta(minutes=minutes))) #This will convert 200 minutes to hours by diving by 60
# Out:
# 0:03:20

# %% [markdown]
# Some of the Key takeaways from the course
#
# <b> Objectives: </b>

# %% [markdown]
# <ul type="square">
#  <li>We learned how to use Jupyter Notebook</li>
#  <li>We learned about Watson Studio</li>
#  <li>We learned to use GitHub</li>
#  <li>We learned different Kernels</li>
#  <li>We learned Python Basic Programming</li>
# </ul>

# %% [markdown]
#  <h2> Author </h2>
#  Ghulam Raza
